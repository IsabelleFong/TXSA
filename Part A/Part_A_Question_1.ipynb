# %%
import re
import nltk, string
from nltk.tokenize import *

#Function for readability
def display_columns_vertical(tokens, num_columns=4):
    col_width = 20
    rows = len(tokens) // num_columns + (1 if len(tokens) % num_columns else 0)
    
    for row in range(rows):
        line = ''
        for col in range(num_columns):
            index = row + col * rows  
            if index < len(tokens):
                line += f'{tokens[index]:<{col_width}}'
            else:
                line += ' ' * col_width
        print(line)


text = "Classification is the task of choosing the correct class label for a given input. In basic classification tasks, each input is considered in isolation from all other inputs, and the set of labels is defined in advance. The basic classification task has a number of interesting variants. For example, in multiclass classification, each instance may be assigned multiple labels; in open-class classification, the set of labels is not defined in advance; and in sequence classification, a list of inputs are jointly classified."

split_text = text.split()
token_num = len(split_text)
print(split_text)
print()
print("Total tokens:",token_num)
print()

display_columns_vertical(split_text, num_columns=4)
# Out:
# ['Classification', 'is', 'the', 'task', 'of', 'choosing', 'the', 'correct', 'class', 'label', 'for', 'a', 'given', 'input.', 'In', 'basic', 'classification', 'tasks,', 'each', 'input', 'is', 'considered', 'in', 'isolation', 'from', 'all', 'other', 'inputs,', 'and', 'the', 'set', 'of', 'labels', 'is', 'defined', 'in', 'advance.', 'The', 'basic', 'classification', 'task', 'has', 'a', 'number', 'of', 'interesting', 'variants.', 'For', 'example,', 'in', 'multiclass', 'classification,', 'each', 'instance', 'may', 'be', 'assigned', 'multiple', 'labels;', 'in', 'open-class', 'classification,', 'the', 'set', 'of', 'labels', 'is', 'not', 'defined', 'in', 'advance;', 'and', 'in', 'sequence', 'classification,', 'a', 'list', 'of', 'inputs', 'are', 'jointly', 'classified.']
#
# Total tokens: 82
#
# Classification      considered          a                   set
# is                  in                  number              of
# the                 isolation           of                  labels
# task                from                interesting         is
# of                  all                 variants.           not
# choosing            other               For                 defined
# the                 inputs,             example,            in
# correct             and                 in                  advance;
# class               the                 multiclass          and
# label               set                 classification,     in
# for                 of                  each                sequence
# a                   labels              instance            classification,
# given               is                  may                 a
# input.              defined             be                  list
# In                  in                  assigned            of
# basic               advance.            multiple            inputs
# classification      The                 labels;             are
# tasks,              basic               in                  jointly
# each                classification      open-class          classified.
# input               task                classification,
# is                  has                 the

# %%
text = "Classification is the task of choosing the correct class label for a given input. In basic classification tasks, each input is considered in isolation from all other inputs, and the set of labels is defined in advance. The basic classification task has a number of interesting variants. For example, in multiclass classification, each instance may be assigned multiple labels; in open-class classification, the set of labels is not defined in advance; and in sequence classification, a list of inputs are jointly classified."

regsplit_text = re.findall(r"\w+", text)
print(regsplit_text)
print()
token_numreg = len(regsplit_text)
print()
print("Total tokens:",token_numreg)
print()
display_columns_vertical(regsplit_text, num_columns=4)
# Out:
# ['Classification', 'is', 'the', 'task', 'of', 'choosing', 'the', 'correct', 'class', 'label', 'for', 'a', 'given', 'input', 'In', 'basic', 'classification', 'tasks', 'each', 'input', 'is', 'considered', 'in', 'isolation', 'from', 'all', 'other', 'inputs', 'and', 'the', 'set', 'of', 'labels', 'is', 'defined', 'in', 'advance', 'The', 'basic', 'classification', 'task', 'has', 'a', 'number', 'of', 'interesting', 'variants', 'For', 'example', 'in', 'multiclass', 'classification', 'each', 'instance', 'may', 'be', 'assigned', 'multiple', 'labels', 'in', 'open', 'class', 'classification', 'the', 'set', 'of', 'labels', 'is', 'not', 'defined', 'in', 'advance', 'and', 'in', 'sequence', 'classification', 'a', 'list', 'of', 'inputs', 'are', 'jointly', 'classified']
#
#
# Total tokens: 83
#
# Classification      considered          a                   the
# is                  in                  number              set
# the                 isolation           of                  of
# task                from                interesting         labels
# of                  all                 variants            is
# choosing            other               For                 not
# the                 inputs              example             defined
# correct             and                 in                  in
# class               the                 multiclass          advance
# label               set                 classification      and
# for                 of                  each                in
# a                   labels              instance            sequence
# given               is                  may                 classification
# input               defined             be                  a
# In                  in                  assigned            list
# basic               advance             multiple            of
# classification      The                 labels              inputs
# tasks               basic               in                  are
# each                classification      open                jointly
# input               task                class               classified
# is                  has                 classification

# %%
text = "Classification is the task of choosing the correct class label for a given input. In basic classification tasks, each input is considered in isolation from all other inputs, and the set of labels is defined in advance. The basic classification task has a number of interesting variants. For example, in multiclass classification, each instance may be assigned multiple labels; in open-class classification, the set of labels is not defined in advance; and in sequence classification, a list of inputs are jointly classified."

nltktokenize_text = word_tokenize(text)
print(nltktokenize_text)
Token_numnltk = len(nltktokenize_text)
print()
print("Total tokens:",Token_numnltk)
print()
display_columns_vertical(nltktokenize_text, num_columns=4)
# Out:
# ['Classification', 'is', 'the', 'task', 'of', 'choosing', 'the', 'correct', 'class', 'label', 'for', 'a', 'given', 'input', '.', 'In', 'basic', 'classification', 'tasks', ',', 'each', 'input', 'is', 'considered', 'in', 'isolation', 'from', 'all', 'other', 'inputs', ',', 'and', 'the', 'set', 'of', 'labels', 'is', 'defined', 'in', 'advance', '.', 'The', 'basic', 'classification', 'task', 'has', 'a', 'number', 'of', 'interesting', 'variants', '.', 'For', 'example', ',', 'in', 'multiclass', 'classification', ',', 'each', 'instance', 'may', 'be', 'assigned', 'multiple', 'labels', ';', 'in', 'open-class', 'classification', ',', 'the', 'set', 'of', 'labels', 'is', 'not', 'defined', 'in', 'advance', ';', 'and', 'in', 'sequence', 'classification', ',', 'a', 'list', 'of', 'inputs', 'are', 'jointly', 'classified', '.']
#
# Total tokens: 94
#
# Classification      in                  of                  set
# is                  isolation           interesting         of
# the                 from                variants            labels
# task                all                 .                   is
# of                  other               For                 not
# choosing            inputs              example             defined
# the                 ,                   ,                   in
# correct             and                 in                  advance
# class               the                 multiclass          ;
# label               set                 classification      and
# for                 of                  ,                   in
# a                   labels              each                sequence
# given               is                  instance            classification
# input               defined             may                 ,
# .                   in                  be                  a
# In                  advance             assigned            list
# basic               .                   multiple            of
# classification      The                 labels              inputs
# tasks               basic               ;                   are
# ,                   classification      in                  jointly
# each                task                open-class          classified
# input               has                 classification      .
# is                  a                   ,
# considered          number              the

# %%
#Stop tokens removal

text = "Classification is the task of choosing the correct class label for a given input. In basic classification tasks, each input is considered in isolation from all other inputs, and the set of labels is defined in advance. The basic classification task has a number of interesting variants. For example, in multiclass classification, each instance may be assigned multiple labels; in open-class classification, the set of labels is not defined in advance; and in sequence classification, a list of inputs are jointly classified."
text_lower = text.lower()
nltktokenizeforremoval_text = word_tokenize(text_lower)
token_numnltk = len(nltktokenizeforremoval_text)
print(nltktokenizeforremoval_text)
print()
print("Total tokens:",token_numnltk)

#Filtering punctuation and stop tokens
stopTokenslist = nltk.corpus.stopwords.words("english") + list(string.punctuation)
filteredTokens = []
stopTokens = []

for word in nltktokenizeforremoval_text:
    if word not in stopTokenslist:
        filteredTokens.append(word)
    else:
        stopTokens.append(word)
print()
print("There are " ,len(filteredTokens), "non stop word or punctuation tokens.")
print()
print(filteredTokens)
print()
print(stopTokens)
print("There are " ,len(stopTokens), "stop word or punctuation tokens.")
# Out:
# ['classification', 'is', 'the', 'task', 'of', 'choosing', 'the', 'correct', 'class', 'label', 'for', 'a', 'given', 'input', '.', 'in', 'basic', 'classification', 'tasks', ',', 'each', 'input', 'is', 'considered', 'in', 'isolation', 'from', 'all', 'other', 'inputs', ',', 'and', 'the', 'set', 'of', 'labels', 'is', 'defined', 'in', 'advance', '.', 'the', 'basic', 'classification', 'task', 'has', 'a', 'number', 'of', 'interesting', 'variants', '.', 'for', 'example', ',', 'in', 'multiclass', 'classification', ',', 'each', 'instance', 'may', 'be', 'assigned', 'multiple', 'labels', ';', 'in', 'open-class', 'classification', ',', 'the', 'set', 'of', 'labels', 'is', 'not', 'defined', 'in', 'advance', ';', 'and', 'in', 'sequence', 'classification', ',', 'a', 'list', 'of', 'inputs', 'are', 'jointly', 'classified', '.']
#
# Total tokens: 94
#
# There are  45 non stop word or punctuation tokens.
#
# ['classification', 'task', 'choosing', 'correct', 'class', 'label', 'given', 'input', 'basic', 'classification', 'tasks', 'input', 'considered', 'isolation', 'inputs', 'set', 'labels', 'defined', 'advance', 'basic', 'classification', 'task', 'number', 'interesting', 'variants', 'example', 'multiclass', 'classification', 'instance', 'may', 'assigned', 'multiple', 'labels', 'open-class', 'classification', 'set', 'labels', 'defined', 'advance', 'sequence', 'classification', 'list', 'inputs', 'jointly', 'classified']
#
# ['is', 'the', 'of', 'the', 'for', 'a', '.', 'in', ',', 'each', 'is', 'in', 'from', 'all', 'other', ',', 'and', 'the', 'of', 'is', 'in', '.', 'the', 'has', 'a', 'of', '.', 'for', ',', 'in', ',', 'each', 'be', ';', 'in', ',', 'the', 'of', 'is', 'not', 'in', ';', 'and', 'in', ',', 'a', 'of', 'are', '.']
# There are  49 stop word or punctuation tokens.
